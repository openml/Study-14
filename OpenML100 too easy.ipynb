# %%
# %matplotlib inline
import openml
import seaborn as sns
import numpy as np
import pandas as pd
import sys
import math
from scipy.stats import norm
from matplotlib import pyplot
import sklearn

# %%
datasets = openml.datasets.list_datasets(tag='OpenML100')

# %%
max_score_per_dataset = {}
for dataset_id in datasets:
    dataset = openml.datasets.get_dataset(dataset_id)
    X, y = dataset.get_data(target=dataset.default_target_attribute)
    n_features = X.shape[1]
    scores = []
    for feat_idx in range(n_features):
        X1 = X[:, feat_idx].reshape((-1, 1))
        imp = sklearn.preprocessing.Imputer(strategy='median')
        X1 = imp.fit_transform(X1)
        if X1.shape[1] == 0:
            continue
        clf = tree.DecisionTreeClassifier(max_leaf_nodes = int(float(dataset.qualities["NumberOfClasses"])))
        clf.fit(X1, y)
        scores.append(clf.score(X1,y))
    
    max_score_per_dataset[dataset_id] = {
        'score': np.max(scores), 
        'argmax': np.argmax(scores),
        'name': dataset.name
    }
    print("Dataset ", dataset.name, " score ", max_score_per_dataset[dataset.dataset_id]["score"])
    
results = pd.DataFrame(max_score_per_dataset).transpose()
# Out:
# Dataset  kr-vs-kp  score  0.683354192741
# Dataset  qsar-biodeg  score  0.745971563981
# Dataset  letter  score  0.1734
# Dataset  pc1  score  0.935978358882
# Dataset  balance-scale  score  0.6352
# Dataset  mfeat-factors  score  0.42
# Dataset  mfeat-fourier  score  0.422
# Dataset  breast-w  score  0.92417739628
# Dataset  mfeat-karhunen  score  0.3515
# Dataset  SpeedDating  score  0.835282883743
# Dataset  mfeat-morphological  score  0.5275
# Dataset  ada_agnostic  score  0.79241560719
# Dataset  mfeat-pixel  score  0.242
# Dataset  car  score  0.700231481481
# Dataset  mozilla4  score  0.934448375683
# Dataset  cmc  score  0.453496266124
# Dataset  mushroom  score  0.790251107829
# Dataset  pc4  score  0.877914951989
# Dataset  pc3  score  0.897632757518
# Dataset  optdigits  score  0.27846975089
# Dataset  credit-approval  score  0.855072463768
# Dataset  credit-g  score  0.717
# Dataset  pendigits  score  0.397197962154
# Dataset  wilt  score  0.946063236206
# Dataset  segment  score  0.639393939394
# Dataset  diabetes  score  0.735677083333
# Dataset  sick  score  0.96553552492
# Dataset  kc2  score  0.854406130268
# Dataset  soybean  score  0.339677891654
# Dataset  kc1  score  0.84542437174
# Dataset  spambase  score  0.793740491198
# Dataset  splice  score  0.633542319749
# Dataset  LED-display-domain-7digit  score  0.21
# Dataset  tic-tac-toe  score  0.653444676409
# Dataset  vowel  score  0.377777777778
# Dataset  vehicle  score  0.486997635934
# Dataset  isolet  score  0.207515711171
# Dataset  scene  score  0.822185292896
# Dataset  waveform-5000  score  0.5732
# Dataset  Australian  score  0.855072463768
# Dataset  satimage  score  0.603421461897
# Dataset  sylva_agnostic  score  0.949287947204
# Dataset  monks-problems-1  score  0.746402877698
# Dataset  monks-problems-2  score  0.657237936772
# Dataset  monks-problems-3  score  0.79963898917
# Dataset  cjs  score  0.46530758226
# Dataset  gina_agnostic  score  0.737312572088
# Dataset  KDDCup09_churn  score  0.92658
# Dataset  KDDCup09_upselling  score  0.93784
# Dataset  GesturePhaseSegmentationProcessed  score  0.451939633343
# Dataset  MagicTelescope  score  0.73349106204
# Dataset  eucalyptus  score  0.529891304348
# Dataset  JapaneseVowels  score  0.34092962554
# Dataset  synthetic_control  score  0.636666666667
# Dataset  Amazon_employee_access  score  0.942109920962
# Dataset  mfeat-zernike  score  0.318
# Dataset  adult  score  0.803386429712
# Dataset  first-order-theorem-proving  score  0.440176528277
# Dataset  electricity  score  0.757393185028
# Dataset  Internet-Advertisements  score  0.912168344007
# Dataset  MiceProtein  score  0.430555555556
# Dataset  cylinder-bands  score  0.618518518519
# Dataset  jm1  score  0.806522737712
# Dataset  artificial-characters  score  0.237815619495
# Dataset  bank-marketing  score  0.883015195417
# Dataset  banknote-authentication  score  0.853498542274
# Dataset  blood-transfusion-service-center  score  0.762032085561
# Dataset  cardiotocography  score  0.486359360301
# Dataset  climate-model-simulation-crashes  score  0.914814814815
# Dataset  cnae-9  score  0.205555555556
# Dataset  eeg-eye-state  score  0.59826435247
# Dataset  irish  score  0.872
# Dataset  gas-drift  score  0.48986340762
# Dataset  har  score  0.550150500049
# Dataset  hill-valley  score  0.542079207921
# Dataset  ilpd  score  0.713550600343
# Dataset  analcatdata_authorship  score  0.678953626635
# Dataset  madelon  score  0.620769230769
# Dataset  nomao  score  0.857014362397
# Dataset  ozone-level-8hr  score  0.938831886346
# Dataset  dresses-sales  score  0.618
# Dataset  phoneme  score  0.754626202813
# Dataset  one-hundred-plants-margin  score  0.133125
# Dataset  one-hundred-plants-shape  score  0.22375
# Dataset  analcatdata_dmft  score  0.22208281054
# Dataset  profb  score  0.678571428571
# Dataset  higgs  score  0.607740948496
# Dataset  wall-robot-navigation  score  0.701612903226
# Dataset  connect-4  score  0.661352635552
# Dataset  semeion  score  0.197740112994
# Dataset  collins  score  1.0
# Dataset  steel-plates-fault  score  0.706336939722
# Dataset  tamilnadu-electricity  score  0.782748301697
# Dataset  Bioresponse  score  0.736870167955
# Dataset  wdbc  score  0.922671353251
# Dataset  PhishingWebsites  score  0.847308909995
# Dataset  micro-mass  score  0.259194395797
# Dataset  texture  score  0.445636363636
# Dataset  mnist_784  score  0.245228571429
# Dataset  one-hundred-plants-texture  score  0.138836772983

# %%
results.sort_values(by='score')
# Out:
#       argmax                               name     score
# 1491       5          one-hundred-plants-margin  0.133125
# 1493       0         one-hundred-plants-texture  0.138837
# 6         12                             letter    0.1734
# 1501     161                            semeion   0.19774
# 1468     545                             cnae-9  0.205556
# 300      583                             isolet  0.207516
# 40496      6          LED-display-domain-7digit      0.21
# 469        1                   analcatdata_dmft  0.222083
# 1492      18           one-hundred-plants-shape   0.22375
# 1459       6              artificial-characters  0.237816
# 20         3                        mfeat-pixel     0.242
# 554      406                          mnist_784  0.245229
# 1515     127                         micro-mass  0.259194
# 28        28                          optdigits   0.27847
# 22         5                      mfeat-zernike     0.318
# 42        21                            soybean  0.339678
# 375        3                     JapaneseVowels   0.34093
# 16         0                     mfeat-karhunen    0.3515
# 307        3                              vowel  0.377778
# 32        13                          pendigits  0.397198
# 12       180                      mfeat-factors      0.42
# 14        72                      mfeat-fourier     0.422
# 4550       0                        MiceProtein  0.430556
# 1475      36        first-order-theorem-proving  0.440177
# 40499     28                            texture  0.445636
# 4538      10  GesturePhaseSegmentationProcessed   0.45194
# 23         3                                cmc  0.453496
# 23380      0                                cjs  0.465308
# 1466      23                   cardiotocography  0.486359
# 54        11                            vehicle  0.486998
# ...      ...                                ...       ...
# 335        1                   monks-problems-3  0.799639
# 1590      10                              adult  0.803386
# 1053       0                                jm1  0.806523
# 312       52                              scene  0.822185
# 40536      0                        SpeedDating  0.835283
# 1067       0                                kc1  0.845424
# 4534      13                   PhishingWebsites  0.847309
# 1462       0            banknote-authentication  0.853499
# 1063       2                                kc2  0.854406
# 40509      7                         Australian  0.855072
# 29         8                    credit-approval  0.855072
# 1486       3                              nomao  0.857014
# 451        2                              irish     0.872
# 1049       0                                pc4  0.877915
# 1461       0                     bank-marketing  0.883015
# 1050       0                                pc3  0.897633
# 1176    1243            Internet-Advertisements  0.912168
# 1467       0   climate-model-simulation-crashes  0.914815
# 1510      20                               wdbc  0.922671
# 15         1                           breast-w  0.924177
# 1112      85                     KDDCup09_churn   0.92658
# 1046       1                           mozilla4  0.934448
# 1068      13                                pc1  0.935978
# 1114     114                 KDDCup09_upselling   0.93784
# 1487      49                    ozone-level-8hr  0.938832
# 4135       0             Amazon_employee_access   0.94211
# 1570       0                               wilt  0.946063
# 1036      63                     sylva_agnostic  0.949288
# 38        19                               sick  0.965536
# 478       19                            collins         1
#
# [100 rows x 3 columns]
