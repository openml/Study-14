# %%
import numpy as np
import pandas as pd
import sklearn.ensemble
import sklearn.model_selection
import sklearn.metrics
import sklearn.pipeline
import sklearn.preprocessing
import openml

# %%
datasets = openml.datasets.list_datasets(tag='OpenML100')

# %%
max_score_per_dataset = {}
for dataset_id in datasets:
    dataset = openml.datasets.get_dataset(dataset_id)
    X, y = dataset.get_data(target=dataset.default_target_attribute)
    n_features = X.shape[1]
    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y)
    scores = []
    for feat_idx in range(n_features):
        X_train_ = X_train[:, feat_idx].reshape((-1, 1))
        X_test_ = X_test[:, feat_idx].reshape((-1, 1))
        imp = sklearn.preprocessing.Imputer(strategy='median')
        X_train_ = imp.fit_transform(X_train_)
        X_test_ = imp.transform(X_test_)
        if X_train_.shape[1] == 0:
            continue
        rf = sklearn.ensemble.RandomForestClassifier()
        rf.fit(X_train_, y_train)
        y_hat = rf.predict(X_test_)
        scores.append(sklearn.metrics.accuracy_score(y_test, y_hat))
    
    max_score_per_dataset[dataset_id] = {
        'score': np.max(scores), 
        'argmax': np.argmax(scores),
        'name': dataset.name
    }
    
results = pd.DataFrame(max_score_per_dataset).transpose()

# %%
results.sort_values(by='score')
# Out:
#       argmax                               name     score
# 1493      19         one-hundred-plants-texture    0.0475
# 1491      42          one-hundred-plants-margin     0.065
# 1492      55           one-hundred-plants-shape     0.085
# 6         10                             letter    0.1668
# 1468     704                             cnae-9  0.181481
# 1515     694                         micro-mass  0.181818
# 300      583                             isolet   0.19641
# 1501     156                            semeion  0.203008
# 469        3                   analcatdata_dmft     0.205
# 22         5                      mfeat-zernike     0.226
# 375        3                     JapaneseVowels  0.236451
# 40496      1          LED-display-domain-7digit      0.24
# 554      406                          mnist_784  0.243086
# 20       184                        mfeat-pixel     0.258
# 307        3                              vowel  0.270161
# 16         0                     mfeat-karhunen     0.272
# 28        61                          optdigits  0.290391
# 14         6                      mfeat-fourier     0.292
# 42        21                            soybean  0.333333
# 12       180                      mfeat-factors     0.352
# 4538       4  GesturePhaseSegmentationProcessed  0.353989
# 18         5                mfeat-morphological     0.368
# 40499     29                            texture  0.373091
# 32        15                          pendigits  0.395924
# 1476       8                          gas-drift  0.459459
# 1466      23                   cardiotocography  0.477444
# 1475       2        first-order-theorem-proving  0.478431
# 23         3                                cmc  0.485095
# 377       49                  synthetic_control      0.52
# 60        15                      waveform-5000      0.52
# ...      ...                                ...       ...
# 335        4                   monks-problems-3  0.820144
# 40536     39                        SpeedDating  0.836754
# 1063       6                                kc2  0.854962
# 40509      7                         Australian  0.855491
# 1486       2                              nomao  0.864918
# 1067      16                                kc1   0.86553
# 29         8                    credit-approval  0.884393
# 4534       7                   PhishingWebsites  0.886035
# 1461      15                     bank-marketing  0.888525
# 1510      27                               wdbc  0.895105
# 1049       3                                pc4   0.89863
# 1050       0                                pc3  0.920716
# 1570       1                               wilt  0.924793
# 1467       0   climate-model-simulation-crashes  0.925926
# 1112     175                     KDDCup09_churn   0.92704
# 1176       2            Internet-Advertisements  0.929268
# 15         1                           breast-w  0.931429
# 1046       1                           mozilla4  0.939028
# 4550       0                        MiceProtein  0.940741
# 1114     114                 KDDCup09_upselling   0.94176
# 1068      20                                pc1  0.942446
# 1487      48                    ozone-level-8hr  0.944795
# 4135       2             Amazon_employee_access  0.945197
# 1036      54                     sylva_agnostic  0.949986
# 38        19                               sick  0.961824
# 24         4                           mushroom  0.986706
# 23380      0                                cjs         1
# 451        2                              irish         1
# 1505       2              tamilnadu-electricity         1
# 478       19                            collins         1
#
# [100 rows x 3 columns]
